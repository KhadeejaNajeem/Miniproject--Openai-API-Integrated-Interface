# %%
# !pip install httpx>=0.25.0

# %%
# !pip install pyaudio
# Out:
# Requirement already satisfied: pyaudio in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (0.2.14)

# %%
# !pip install googletrans
# Out:
# Requirement already satisfied: googletrans in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (3.0.0)
# Requirement already satisfied: httpx==0.13.3 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from googletrans) (0.13.3)
# Requirement already satisfied: certifi in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans) (2024.2.2)
# Requirement already satisfied: hstspreload in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans) (2024.5.1)
# Requirement already satisfied: sniffio in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans) (1.3.1)
# Requirement already satisfied: chardet==3.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans) (3.0.4)
# Requirement already satisfied: idna==2.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans) (0.9.0)
# Requirement already satisfied: h2==3.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans) (3.0.0)

# %%
# !pip install speechrecognition
# Out:
# Requirement already satisfied: speechrecognition in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (3.10.3)
# Requirement already satisfied: requests>=2.26.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from speechrecognition) (2.31.0)
# Requirement already satisfied: typing-extensions in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from speechrecognition) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26.0->speechrecognition) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26.0->speechrecognition) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26.0->speechrecognition) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26.0->speechrecognition) (2024.2.2)

# %%
import speech_recognition as sr
from googletrans import Translator
import pyaudio
import wave
import os
import tkinter as tk

# Import httpx for making HTTP requests (if using OpenAI)
import httpx
import openai
# Set your OpenAI API key (optional)
openai.api_key = "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"

def record_audio(filename, duration=5):
    """
    Records audio and saves it to a WAV file.

    Args:
        filename (str): Name of the file to save the audio to.
        duration (int): Duration of the recording in seconds. Default is 5 seconds.
    """
    chunk = 1024
    format = pyaudio.paInt16
    channels = 1
    rate = 44100

    audio = pyaudio.PyAudio()

    stream = audio.open(format=format, channels=channels,
                        rate=rate, input=True,
                        frames_per_buffer=chunk)

    print("Recording...")
    frames = []

    for i in range(0, int(rate / chunk * duration)):
        data = stream.read(chunk)
        frames.append(data)

    print("Finished recording.")

    stream.stop_stream()
    stream.close()
    audio.terminate()

    # Save the recorded audio to a WAV file
    wf = wave.open(filename, 'wb')
    wf.setnchannels(channels)
    wf.setsampwidth(audio.get_sample_size(format))
    wf.setframerate(rate)
    wf.writeframes(b''.join(frames))
    wf.close()

def malayalam_speech_to_text(audio_file):
    recognizer = sr.Recognizer()

    # Load the audio file
    with sr.AudioFile(audio_file) as source:
        audio_data = recognizer.record(source)

    try:
        # Recognize speech using Google Web Speech API
        text = recognizer.recognize_google(audio_data, language="ml-IN")
        return text
    except sr.UnknownValueError:
        return "സ്വന്തമായ വാക്കുകൾ പിന്തുടരുക..."
    except sr.RequestError:
        return "API അനുവദനീയത ലഭ്യമല്ല..."


def translate_to_english(malayalam_text):
    translator = Translator()
    translated = translator.translate(malayalam_text, src="ml", dest="en")
    return translated.text

def ask_gpt(question):
    # Use httpx for making HTTP requests to OpenAI API
    client = httpx.Client(headers={"Authorization": f"Bearer {openai.api_key}"})
    response = client.post(
        "https://api.openai.com/v1/completions",
        json={
            "engine": "text-davinci-002",
            "prompt": question,
            "max_tokens": 50
        }
    )
    response.raise_for_status()  # Raise an exception for non-2xx status codes
    return response.json()["choices"][0]["text"].strip()

def start_recording():
    global filename
    filename = "recorded_audio.wav"
    record_audio(filename)
    result = malayalam_speech_to_text(filename)
    translated_text = translate_to_english(result)

    if openai.api_key:  # Check if OpenAI API key is provided
        response = ask_gpt(translated_text)
    else:
        response = "Please provide your OpenAI API key to use ChatGPT."

    text_display.config(state=tk.NORMAL)
    text_display.delete("1.0", tk.END)
    text_display.insert(tk.END, f"Malayalam Text:\n{result}\n\nTranslated to English:\n{translated_text}\n\nChatGPT Response:\n{response}")
    text_display.config(state=tk.DISABLED)

# Create the GUI window
root = tk.Tk()
root.title("Audio Transcription, Translation, and ChatGPT")

# Create a text widget for displaying the results
text_display = tk.Text(root, width=60, height=15)
text_display.pack(pady=20)
text_display.config(state=tk.DISABLED)

# Create "Start Recording" button
start_button = tk.Button(root, text="Start Recording", command=start_recording)
start_button.pack(pady=10)

# Create "Quit" button
quit_button = tk.Button(root, text="Quit", command=root.quit)
quit_button.pack(pady=10)

root.mainloop()

# Delete the recorded audio file
if os.path.exists(filename):
    os.remove(filename)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 10
#       8 # Import httpx for making HTTP requests (if using OpenAI)
#       9 import httpx
# ---> 10 import openai
#      11 # Set your OpenAI API key (optional)
#      12 openai.api_key = "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"
#
# ModuleNotFoundError: No module named 'openai'

# %%
# !pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.25.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.3.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Using cached httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting pydantic<3,>=1.9.0 (from openai)
#   Downloading pydantic-2.7.1-py3-none-any.whl.metadata (107 kB)
#      ---------------------------------------- 0.0/107.3 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/107.3 kB ? eta -:--:--
#      ------------------------------------ - 102.4/107.3 kB 1.5 MB/s eta 0:00:01
#      -------------------------------------- 107.3/107.3 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai) (1.3.1)
# Collecting tqdm>4 (from openai)
#   Downloading tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ---------------------------------------- 57.6/57.6 kB ? eta 0:00:00
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3.5.0->openai) (2.10)
# Requirement already satisfied: certifi in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=1.9.0->openai)
#   Using cached annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.18.2 (from pydantic<3,>=1.9.0->openai)
#   Downloading pydantic_core-2.18.2-cp312-none-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: colorama in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading openai-1.25.1-py3-none-any.whl (312 kB)
#    ---------------------------------------- 0.0/312.9 kB ? eta -:--:--
#    ---------------------------- ---------- 225.3/312.9 kB 14.3 MB/s eta 0:00:01
#    ---------------------------------------- 312.9/312.9 kB 6.4 MB/s eta 0:00:00
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Downloading pydantic-2.7.1-py3-none-any.whl (409 kB)
#    ---------------------------------------- 0.0/409.3 kB ? eta -:--:--
#    --------------------------------------- 409.3/409.3 kB 12.9 MB/s eta 0:00:00
# Downloading pydantic_core-2.18.2-cp312-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    --------------- ------------------------ 0.7/1.9 MB 16.0 MB/s eta 0:00:01
#    ------------------------------ --------- 1.5/1.9 MB 15.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 15.3 MB/s eta 0:00:00
# Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.3 kB ? eta -:--:--
#    ---------------------------------------- 78.3/78.3 kB 4.5 MB/s eta 0:00:00
# Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: tqdm, pydantic-core, h11, distro, annotated-types, pydantic, httpcore, httpx, openai
#   Attempting uninstall: h11
#     Found existing installation: h11 0.9.0
#     Uninstalling h11-0.9.0:
#       Successfully uninstalled h11-0.9.0
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 0.9.1
#     Uninstalling httpcore-0.9.1:
#       Successfully uninstalled httpcore-0.9.1
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.13.3
#     Uninstalling httpx-0.13.3:
#       Successfully uninstalled httpx-0.13.3
# Successfully installed annotated-types-0.6.0 distro-1.9.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.25.1 pydantic-2.7.1 pydantic-core-2.18.2 tqdm-4.66.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# googletrans 3.0.0 requires httpx==0.13.3, but you have httpx 0.27.0 which is incompatible.

# %%
# !pip install translate
# Out:
# Collecting translate
#   Downloading translate-3.6.1-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting click (from translate)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting lxml (from translate)
#   Downloading lxml-5.2.1-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: requests in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from translate) (2.31.0)
# Collecting libretranslatepy==2.1.1 (from translate)
#   Downloading libretranslatepy-2.1.1-py3-none-any.whl.metadata (233 bytes)
# Requirement already satisfied: colorama in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from click->translate) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests->translate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests->translate) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests->translate) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests->translate) (2024.2.2)
# Downloading translate-3.6.1-py2.py3-none-any.whl (12 kB)
# Downloading libretranslatepy-2.1.1-py3-none-any.whl (3.2 kB)
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ---------------------------------------- 0.0/97.9 kB ? eta -:--:--
#    ------------------------------------- -- 92.2/97.9 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 97.9/97.9 kB 2.8 MB/s eta 0:00:00
# Downloading lxml-5.2.1-cp312-cp312-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.8 MB 10.9 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.1/3.8 MB 13.7 MB/s eta 0:00:01
#    --------------------- ------------------ 2.1/3.8 MB 16.4 MB/s eta 0:00:01
#    --------------------------------- ------ 3.2/3.8 MB 18.3 MB/s eta 0:00:01
#    ---------------------------------------  3.8/3.8 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 17.4 MB/s eta 0:00:00
# Installing collected packages: libretranslatepy, lxml, click, translate
# Successfully installed click-8.1.7 libretranslatepy-2.1.1 lxml-5.2.1 translate-3.6.1

# %%
import speech_recognition as sr
import translate  # Replace googletrans with translate
import pyaudio
import wave
import os
import tkinter as tk
import openai
# OpenAI API key (optional)
openai.api_key = "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"

def record_audio(filename, duration=5):
    """
    Records audio and saves it to a WAV file.

    Args:
        filename (str): Name of the file to save the audio to.
        duration (int): Duration of the recording in seconds. Default is 5 seconds.
    """
    chunk = 1024
    format = pyaudio.paInt16
    channels = 1
    rate = 44100

    audio = pyaudio.PyAudio()

    stream = audio.open(format=format, channels=channels,
                        rate=rate, input=True,
                        frames_per_buffer=chunk)

    print("Recording...")
    frames = []

    for i in range(0, int(rate / chunk * duration)):
        data = stream.read(chunk)
        frames.append(data)

    print("Finished recording.")

    stream.stop_stream()
    stream.close()
    audio.terminate()

    # Save the recorded audio to a WAV file
    wf = wave.open(filename, 'wb')
    wf.setnchannels(channels)
    wf.setsampwidth(audio.get_sample_size(format))
    wf.setframerate(rate)
    wf.writeframes(b''.join(frames))
    wf.close()

def malayalam_speech_to_text(audio_file):
    recognizer = sr.Recognizer()

    # Load the audio file
    with sr.AudioFile(audio_file) as source:
        audio_data = recognizer.record(source)

    try:
        # Recognize speech using Google Web Speech API
        text = recognizer.recognize_google(audio_data, language="ml-IN")
        return text
    except sr.UnknownValueError:
        return "സ്വന്തമായ വാക്കുകൾ പിന്തുടരുക..."
    except sr.RequestError:
        return "API അനുവദനീയത ലഭ്യമല്ല..."


def translate_to_english(malayalam_text):
    translated = translate.Translator().to_english(malayalam_text)
    return translated.text

def ask_gpt(question):
    # OpenAI API key functionality remains the same (optional)
    ...

def start_recording():
    global filename
    filename = "recorded_audio.wav"
    record_audio(filename)
    result = malayalam_speech_to_text(filename)
    translated_text = translate_to_english(result)

    if openai.api_key:  # Check if OpenAI API key is provided
        response = ask_gpt(translated_text)
    else:
        response = "Please provide your OpenAI API key to use ChatGPT."

    text_display.config(state=tk.NORMAL)
    text_display.delete("1.0", tk.END)
    text_display.insert(tk.END, f"Malayalam Text:\n{result}\n\nTranslated to English:\n{translated_text}\n\nChatGPT Response:\n{response}")
    text_display.config(state=tk.DISABLED)

# Create the GUI window
root = tk.Tk()
root.title("Audio Transcription, Translation, and ChatGPT")

# Create a text widget for displaying the results
text_display = tk.Text(root, width=60, height=15)
text_display.pack(pady=20)
text_display.config(state=tk.DISABLED)

# Create "Start Recording" button
start_button = tk.Button(root, text="Start Recording", command=start_recording)
start_button.pack(pady=10)

# Create "Quit" button
quit_button = tk.Button(root, text="Quit", command=root.quit)
quit_button.pack(pady=10)

root.mainloop()

# Delete the recorded audio file
if os.path.exists(filename):
    os.remove(filename)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 7
#       5 import os
#       6 import tkinter as tk
# ----> 7 import openai
#       8 # OpenAI API key (optional)
#       9 openai.api_key = "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"
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\__init__.py:8
#       5 import os as _os
#       6 from typing_extensions import override
# ----> 8 from . import types
#       9 from ._types import NOT_GIVEN, NoneType, NotGiven, Transport, ProxiesTypes
#      10 from ._utils import file_from_path
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\types\__init__.py:5
#       1 # File generated from our OpenAPI spec by Stainless. See CONTRIBUTING.md for details.
#       3 from __future__ import annotations
# ----> 5 from .batch import Batch as Batch
#       6 from .image import Image as Image
#       7 from .model import Model as Model
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\types\batch.py:7
#       4 from typing import List, Optional
#       5 from typing_extensions import Literal
# ----> 7 from .._models import BaseModel
#       8 from .batch_error import BatchError
#       9 from .batch_request_counts import BatchRequestCounts
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\_models.py:24
#      21 import pydantic.generics
#      22 from pydantic.fields import FieldInfo
# ---> 24 from ._types import (
#      25     Body,
#      26     IncEx,
#      27     Query,
#      28     ModelT,
#      29     Headers,
#      30     Timeout,
#      31     NotGiven,
#      32     AnyMapping,
#      33     HttpxRequestFiles,
#      34 )
#      35 from ._utils import (
#      36     PropertyInfo,
#      37     is_list,
#    (...)
#      47     strip_annotated_type,
#      48 )
#      49 from ._compat import (
#      50     PYDANTIC_V2,
#      51     ConfigDict,
#    (...)
#      60     field_get_default,
#      61 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\_types.py:23
#      21 import httpx
#      22 import pydantic
# ---> 23 from httpx import URL, Proxy, Timeout, Response, BaseTransport, AsyncBaseTransport
#      25 if TYPE_CHECKING:
#      26     from ._models import BaseModel
#
# ImportError: cannot import name 'BaseTransport' from 'httpx' (C:\Users\Najeem\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpx\__init__.py)

# %%
# !pip install httpx>=0.25.0

# %%
import speech_recognition as sr
import translate  # Replace googletrans with translate
import pyaudio
import wave
import os
import tkinter as tk
import openai

# OpenAI API key (optional)
openai.api_key = "YOUR_OPENAI_API_KEY"

def record_audio(filename, duration=5):
    """
    Records audio and saves it to a WAV file.

    Args:
        filename (str): Name of the file to save the audio to.
        duration (int): Duration of the recording in seconds. Default is 5 seconds.
    """
    chunk = 1024
    format = pyaudio.paInt16
    channels = 1
    rate = 44100

    audio = pyaudio.PyAudio()

    stream = audio.open(format=format, channels=channels,
                        rate=rate, input=True,
                        frames_per_buffer=chunk)

    print("Recording...")
    frames = []

    for i in range(0, int(rate / chunk * duration)):
        data = stream.read(chunk)
        frames.append(data)

    print("Finished recording.")

    stream.stop_stream()
    stream.close()
    audio.terminate()

    # Save the recorded audio to a WAV file
    wf = wave.open(filename, 'wb')
    wf.setnchannels(channels)
    wf.setsampwidth(audio.get_sample_size(format))
    wf.setframerate(rate)
    wf.writeframes(b''.join(frames))
    wf.close()

def malayalam_speech_to_text(audio_file):
    recognizer = sr.Recognizer()

    # Load the audio file
    with sr.AudioFile(audio_file) as source:
        audio_data = recognizer.record(source)

    try:
        # Recognize speech using Google Web Speech API
        text = recognizer.recognize_google(audio_data, language="ml-IN")
        return text
    except sr.UnknownValueError:
        return "സ്വന്തമായ വാക്കുകൾ പിന്തുടരുക..."
    except sr.RequestError:
        return "API അനുവദനീയത ലഭ്യമല്ല..."


def translate_to_english(malayalam_text):
    translated = translate.Translator(to_lang="en").translate(malayalam_text)
    return translated

def ask_gpt(question):
    # OpenAI API key functionality remains the same (optional)
    ...

def start_recording():
    global filename
    filename = "recorded_audio.wav"
    record_audio(filename)
    result = malayalam_speech_to_text(filename)
    translated_text = translate_to_english(result)

    if openai.api_key:  # Check if OpenAI API key is provided
        response = ask_gpt(translated_text)
    else:
        response = "Please provide your OpenAI API key to use ChatGPT."

    text_display.config(state=tk.NORMAL)
    text_display.delete("1.0", tk.END)
    text_display.insert(tk.END, f"Malayalam Text:\n{result}\n\nTranslated to English:\n{translated_text}\n\nChatGPT Response:\n{response}")
    text_display.config(state=tk.DISABLED)

# Create the GUI window
root = tk.Tk()
root.title("Audio Transcription, Translation, and ChatGPT")

# Create a text widget for displaying the results
text_display = tk.Text(root, width=60, height=15)
text_display.pack(pady=20)
text_display.config(state=tk.DISABLED)

# Create "Start Recording" button
start_button = tk.Button(root, text="Start Recording", command=start_recording)
start_button.pack(pady=10)

# Create "Quit" button
quit_button = tk.Button(root, text="Quit", command=root.quit)
quit_button.pack(pady=10)

root.mainloop()

# Delete the recorded audio file
if os.path.exists(filename):
    os.remove(filename)
# Out:
# Recording...
# Finished recording.

# %%
import speech_recognition as sr
import translate  # Replace googletrans with translate
import pyaudio
import wave
import os
import tkinter as tk
import openai

# OpenAI API key (optional)
openai.api_key = "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"

def record_audio(filename, duration=5):
    """
    Records audio and saves it to a WAV file.

    Args:
        filename (str): Name of the file to save the audio to.
        duration (int): Duration of the recording in seconds. Default is 5 seconds.
    """
    chunk = 1024
    format = pyaudio.paInt16
    channels = 1
    rate = 44100

    audio = pyaudio.PyAudio()

    stream = audio.open(format=format, channels=channels,
                        rate=rate, input=True,
                        frames_per_buffer=chunk)

    print("Recording...")
    frames = []

    for i in range(0, int(rate / chunk * duration)):
        data = stream.read(chunk)
        frames.append(data)

    print("Finished recording.")

    stream.stop_stream()
    stream.close()
    audio.terminate()

    # Save the recorded audio to a WAV file
    wf = wave.open(filename, 'wb')
    wf.setnchannels(channels)
    wf.setsampwidth(audio.get_sample_size(format))
    wf.setframerate(rate)
    wf.writeframes(b''.join(frames))
    wf.close()

def malayalam_speech_to_text(audio_file):
    recognizer = sr.Recognizer()

    # Load the audio file
    with sr.AudioFile(audio_file) as source:
        audio_data = recognizer.record(source)

    try:
        # Recognize speech using Google Web Speech API
        text = recognizer.recognize_google(audio_data, language="ml-IN")
        return text
    except sr.UnknownValueError:
        return "സ്വന്തമായ വാക്കുകൾ പിന്തുടരുക..."
    except sr.RequestError:
        return "API അനുവദനീയത ലഭ്യമല്ല..."


'''def translate_to_english(malayalam_text):
    translated = translate.Translator(to_lang="en").translate(malayalam_text)
    return translated'''

def translate_to_english(malayalam_text):
    translator = translate.Translator(to_lang="en")
    translated = translator.translate(malayalam_text)
    return translated


def ask_gpt(question):
    # Placeholder implementation: Return a fixed response
    return "This is a placeholder response from ChatGPT."

def start_recording():
    global filename
    filename = "recorded_audio.wav"
    record_audio(filename)
    result = malayalam_speech_to_text(filename)
    translated_text = translate_to_english(result)

    response = ask_gpt(translated_text)

    text_display.config(state=tk.NORMAL)
    text_display.delete("1.0", tk.END)
    text_display.insert(tk.END, f"Malayalam Text:\n{result}\n\nTranslated to English:\n{translated_text}\n\nChatGPT Response:\n{response}")
    text_display.config(state=tk.DISABLED)

# Create the GUI window
root = tk.Tk()
root.title("Audio Transcription, Translation, and ChatGPT")

# Create a text widget for displaying the results
text_display = tk.Text(root, width=60, height=15)
text_display.pack(pady=20)
text_display.config(state=tk.DISABLED)

# Create "Start Recording" button
start_button = tk.Button(root, text="Start Recording", command=start_recording)
start_button.pack(pady=10)

# Create "Quit" button
quit_button = tk.Button(root, text="Quit", command=root.quit)
quit_button.pack(pady=10)

root.mainloop()

# Delete the recorded audio file
if os.path.exists(filename):
    os.remove(filename)
# Out:
# Recording...
# Finished recording.
# Recording...
# Finished recording.

# %%
# !pip install translate
# Out:
# Requirement already satisfied: translate in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (3.6.1)
# Requirement already satisfied: click in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from translate) (8.1.7)
# Requirement already satisfied: lxml in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from translate) (5.2.1)
# Requirement already satisfied: requests in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from translate) (2.31.0)
# Requirement already satisfied: libretranslatepy==2.1.1 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from translate) (2.1.1)
# Requirement already satisfied: colorama in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from click->translate) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests->translate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests->translate) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests->translate) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests->translate) (2024.2.2)

# %%
# !pip install openai==0.28
# Out:
# Collecting openai==0.28
#   Downloading openai-0.28.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests>=2.20 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai==0.28) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai==0.28) (4.66.4)
# Collecting aiohttp (from openai==0.28)
#   Downloading aiohttp-3.9.5-cp312-cp312-win_amd64.whl.metadata (7.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai==0.28) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai==0.28) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai==0.28) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai==0.28) (2024.2.2)
# Collecting aiosignal>=1.1.2 (from aiohttp->openai==0.28)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai==0.28) (23.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp->openai==0.28)
#   Downloading frozenlist-1.4.1-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->openai==0.28)
#   Downloading multidict-6.0.5-cp312-cp312-win_amd64.whl.metadata (4.3 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->openai==0.28)
#   Downloading yarl-1.9.4-cp312-cp312-win_amd64.whl.metadata (32 kB)
# Requirement already satisfied: colorama in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from tqdm->openai==0.28) (0.4.6)
# Downloading openai-0.28.0-py3-none-any.whl (76 kB)
#    ---------------------------------------- 0.0/76.5 kB ? eta -:--:--
#    --------------------- ------------------ 41.0/76.5 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 76.5/76.5 kB 1.4 MB/s eta 0:00:00
# Downloading aiohttp-3.9.5-cp312-cp312-win_amd64.whl (369 kB)
#    ---------------------------------------- 0.0/369.0 kB ? eta -:--:--
#    ---- ---------------------------------- 41.0/369.0 kB 991.0 kB/s eta 0:00:01
#    ----------------- ---------------------- 163.8/369.0 kB 2.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 204.8/369.0 kB 1.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 327.7/369.0 kB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 369.0/369.0 kB 1.6 MB/s eta 0:00:00
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading frozenlist-1.4.1-cp312-cp312-win_amd64.whl (50 kB)
#    ---------------------------------------- 0.0/50.5 kB ? eta -:--:--
#    ---------------------------------------- 50.5/50.5 kB 1.3 MB/s eta 0:00:00
# Downloading multidict-6.0.5-cp312-cp312-win_amd64.whl (27 kB)
# Downloading yarl-1.9.4-cp312-cp312-win_amd64.whl (76 kB)
#    ---------------------------------------- 0.0/76.4 kB ? eta -:--:--
#    ---------------------------------------- 76.4/76.4 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: multidict, frozenlist, yarl, aiosignal, aiohttp, openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.25.1
#     Uninstalling openai-1.25.1:
#       Successfully uninstalled openai-1.25.1
# Successfully installed aiohttp-3.9.5 aiosignal-1.3.1 frozenlist-1.4.1 multidict-6.0.5 openai-0.28.0 yarl-1.9.4

# %%
# !pip install --upgrade openai
# Out:
# Requirement already satisfied: openai in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (0.28.0)
# Collecting openai
#   Using cached openai-1.25.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai) (2.7.1)
# Requirement already satisfied: sniffio in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3.5.0->openai) (2.10)
# Requirement already satisfied: certifi in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.18.2)
# Requirement already satisfied: colorama in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Using cached openai-1.25.1-py3-none-any.whl (312 kB)
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 0.28.0
#     Uninstalling openai-0.28.0:
#       Successfully uninstalled openai-0.28.0
# Successfully installed openai-1.25.1

# %%
import speech_recognition as sr
import translate  # Replace googletrans with translate
import pyaudio
import wave
import os
import tkinter as tk
import openai

# OpenAI API key (optional)
openai.api_key = "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"

def record_audio(filename, duration=5):
    """
    Records audio and saves it to a WAV file.

    Args:
        filename (str): Name of the file to save the audio to.
        duration (int): Duration of the recording in seconds. Default is 5 seconds.
    """
    chunk = 1024
    format = pyaudio.paInt16
    channels = 1
    rate = 44100

    audio = pyaudio.PyAudio()

    stream = audio.open(format=format, channels=channels,
                        rate=rate, input=True,
                        frames_per_buffer=chunk)

    print("Recording...")
    frames = []

    for i in range(0, int(rate / chunk * duration)):
        data = stream.read(chunk)
        frames.append(data)

    print("Finished recording.")

    stream.stop_stream()
    stream.close()
    audio.terminate()

    # Save the recorded audio to a WAV file
    wf = wave.open(filename, 'wb')
    wf.setnchannels(channels)
    wf.setsampwidth(audio.get_sample_size(format))
    wf.setframerate(rate)
    wf.writeframes(b''.join(frames))
    wf.close()

def malayalam_speech_to_text(audio_file):
    recognizer = sr.Recognizer()

    # Load the audio file
    with sr.AudioFile(audio_file) as source:
        audio_data = recognizer.record(source)

    try:
        # Recognize speech using Google Web Speech API
        text = recognizer.recognize_google(audio_data, language="ml-IN")
        return text
    except sr.UnknownValueError:
        return "സ്വന്തമായ വാക്കുകൾ പിന്തുടരുക..."
    except sr.RequestError:
        return "API അനുവദനീയത ലഭ്യമല്ല..."


'''def translate_to_english(malayalam_text):
    translated = translate.translate(malayalam_text, src='ml', dest='en')
    return translated.text'''
def translate_to_english(malayalam_text):
    try:
        translated = translate.translate(malayalam_text, src='ml', dest='en')
        return translated.text
    except Exception as e:
        return f"Translation Error: {str(e)}"


'''def ask_gpt(question):
    response = openai.Completion.create(
        engine="davinci", 
        prompt=question, 
        max_tokens=50
    )
    return response.choices[0].text.strip()'''

def ask_gpt(question):
    response = openai.Completion.create(
        engine="text-davinci-002",  # Specify the engine to use
        prompt=question,
        max_tokens=50
    )
    return response.choices[0].text.strip()


def start_recording():
    global filename
    filename = "recorded_audio.wav"
    record_audio(filename)
    result = malayalam_speech_to_text(filename)
    translated_text = translate_to_english(result)

    if openai.api_key:  # Check if OpenAI API key is provided
        response = ask_gpt(translated_text)
    else:
        response = "Please provide your OpenAI API key to use ChatGPT."

    text_display.config(state=tk.NORMAL)
    text_display.delete("1.0", tk.END)
    text_display.insert(tk.END, f"Malayalam Text:\n{result}\n\nTranslated to English:\n{translated_text}\n\nChatGPT Response:\n{response}")
    text_display.config(state=tk.DISABLED)

# Create the GUI window
root = tk.Tk()
root.title("Audio Transcription, Translation, and ChatGPT")

# Create a text widget for displaying the results
text_display = tk.Text(root, width=60, height=15)
text_display.pack(pady=20)
text_display.config(state=tk.DISABLED)

# Create "Start Recording" button
start_button = tk.Button(root, text="Start Recording", command=start_recording)
start_button.pack(pady=10)

# Create "Quit" button
quit_button = tk.Button(root, text="Quit", command=root.quit)
quit_button.pack(pady=10)

root.mainloop()

# Delete the recorded audio file
if os.path.exists(filename):
    os.remove(filename)

# %%
# !pip install --upgrade openai
# Out:
# Requirement already satisfied: openai in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (1.25.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai) (2.7.1)
# Requirement already satisfied: sniffio in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3.5.0->openai) (2.10)
# Requirement already satisfied: certifi in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.18.2)
# Requirement already satisfied: colorama in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from tqdm>4->openai) (0.4.6)

# %%
# !pip install openai==0.28
# Out:
# Collecting openai==0.28
#   Using cached openai-0.28.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests>=2.20 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai==0.28) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai==0.28) (4.66.4)
# Requirement already satisfied: aiohttp in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai==0.28) (3.9.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai==0.28) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai==0.28) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai==0.28) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai==0.28) (2024.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai==0.28) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai==0.28) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai==0.28) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai==0.28) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai==0.28) (1.9.4)
# Requirement already satisfied: colorama in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from tqdm->openai==0.28) (0.4.6)
# Using cached openai-0.28.0-py3-none-any.whl (76 kB)
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.25.1
#     Uninstalling openai-1.25.1:
#       Successfully uninstalled openai-1.25.1
# Successfully installed openai-0.28.0

# %%
# !pip show openai
# Out:
# Name: openai
# Version: 0.28.0
# Summary: Python client library for the OpenAI API
# Home-page: https://github.com/openai/openai-python
# Author: OpenAI
# Author-email: support@openai.com
# License:
# Location: C:\Users\Najeem\AppData\Local\Programs\Python\Python312\Lib\site-packages
# Requires: aiohttp, requests, tqdm
# Required-by:

# %%
import speech_recognition as sr
import translate  # Replace googletrans with translate
import pyaudio
import wave
import os
import tkinter as tk
import openai

# OpenAI API key (optional)
openai.api_key = "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"

def record_audio(filename, duration=5):
    """
    Records audio and saves it to a WAV file.

    Args:
        filename (str): Name of the file to save the audio to.
        duration (int): Duration of the recording in seconds. Default is 5 seconds.
    """
    chunk = 1024
    format = pyaudio.paInt16
    channels = 1
    rate = 44100

    audio = pyaudio.PyAudio()

    stream = audio.open(format=format, channels=channels,
                        rate=rate, input=True,
                        frames_per_buffer=chunk)

    print("Recording...")
    frames = []

    for i in range(0, int(rate / chunk * duration)):
        data = stream.read(chunk)
        frames.append(data)

    print("Finished recording.")

    stream.stop_stream()
    stream.close()
    audio.terminate()

    # Save the recorded audio to a WAV file
    wf = wave.open(filename, 'wb')
    wf.setnchannels(channels)
    wf.setsampwidth(audio.get_sample_size(format))
    wf.setframerate(rate)
    wf.writeframes(b''.join(frames))
    wf.close()

def malayalam_speech_to_text(audio_file):
    recognizer = sr.Recognizer()

    # Load the audio file
    with sr.AudioFile(audio_file) as source:
        audio_data = recognizer.record(source)

    try:
        # Recognize speech using Google Web Speech API
        text = recognizer.recognize_google(audio_data, language="ml-IN")
        return text
    except sr.UnknownValueError:
        return "സ്വന്തമായ വാക്കുകൾ പിന്തുടരുക..."
    except sr.RequestError:
        return "API അനുവദനീയത ലഭ്യമല്ല..."


'''def translate_to_english(malayalam_text):
    translated = translate.translate(malayalam_text, src='ml', dest='en')
    return translated.text'''
def translate_to_english(malayalam_text):
    try:
        translated = translate(malayalam_text, to_lang='en', from_lang='ml')
        return translated.text
    except Exception as e:
        return f"Translation Error: {str(e)}"
        
'''def translate_to_english(malayalam_text):
    translator = t(to_lang="en", from_lang="ml")
    translated_text = translator.translate(malayalam_text)
    return translated_text'''

'''def ask_gpt(question):
    response = openai.Completion.create(
        engine="davinci", 
        prompt=question, 
        max_tokens=50
    )
    return response.choices[0].text.strip()'''

def ask_gpt(question):
    response = openai.Completion.create(
        engine="text-davinci-002",  # Specify the engine to use
        prompt=question,
        max_tokens=50
    )
    return response.choices[0].text.strip()


def start_recording():
    global filename
    filename = "recorded_audio.wav"
    record_audio(filename)
    result = malayalam_speech_to_text(filename)
    translated_text = translate_to_english(result)

    if openai.api_key:  # Check if OpenAI API key is provided
        response = ask_gpt(translated_text)
    else:
        response = "Please provide your OpenAI API key to use ChatGPT."

    text_display.config(state=tk.NORMAL)
    text_display.delete("1.0", tk.END)
    text_display.insert(tk.END, f"Malayalam Text:\n{result}\n\nTranslated to English:\n{translated_text}\n\nChatGPT Response:\n{response}")
    text_display.config(state=tk.DISABLED)

# Create the GUI window
root = tk.Tk()
root.title("Audio Transcription, Translation, and ChatGPT")

# Create a text widget for displaying the results
text_display = tk.Text(root, width=60, height=15)
text_display.pack(pady=20)
text_display.config(state=tk.DISABLED)

# Create "Start Recording" button
start_button = tk.Button(root, text="Start Recording", command=start_recording)
start_button.pack(pady=10)

# Create "Quit" button
quit_button = tk.Button(root, text="Quit", command=root.quit)
quit_button.pack(pady=10)

root.mainloop()

# Delete the recorded audio file
if os.path.exists(filename):
    os.remove(filename)
# Out:
# Recording...
# Finished recording.
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Najeem\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1967, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Najeem\AppData\Local\Temp\ipykernel_2528\1426127496.py", line 109, in start_recording
#     response = ask_gpt(translated_text)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Najeem\AppData\Local\Temp\ipykernel_2528\1426127496.py", line 93, in ask_gpt
#     response = openai.Completion.create(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Najeem\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\api_resources\completion.py", line 25, in create
#     return super().create(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Najeem\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\api_resources\abstract\engine_api_resource.py", line 153, in create
#     response, _, api_key = requestor.request(
#                            ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Najeem\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\api_requestor.py", line 298, in request
#     resp, got_stream = self._interpret_response(result, stream)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Najeem\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\api_requestor.py", line 700, in _interpret_response
#     self._interpret_response_line(
#   File "C:\Users\Najeem\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\api_requestor.py", line 765, in _interpret_response_line
#     raise self.handle_error_response(
# openai.error.InvalidRequestError: The model `text-davinci-002` has been deprecated, learn more here: https://platform.openai.com/docs/deprecations

# %%
import httpcore

setattr(httpcore, 'SyncHTTPTransport', 'AsyncHTTPProxy')

import tkinter as tk
from tkinter import Text, Scrollbar, messagebox
from googletrans import Translator
import speech_recognition as sr
import threading
import openai as OpenAI
# from openai import OpenAI
import sounddevice as sd
import numpy as np


openai.api_key="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"

def chat_with_gpt(prompt):
  completion = openai.Completion.create(
    engine="gpt-3.5-turbo-instruct",  # Replace with gpt-3.5-turbo-instruct
    prompt=prompt,
    max_tokens=150
  )
  txt = completion.choices[0].text
  print(txt)
  return txt

'''def chat_with_gpt(prompt):
    completion = openai.Completion.create(
        model= "text-davinci-002",     #"gpt-3.5-turbo",  # 
        messages=[
            {
                "role": "user",
                "content": prompt,
            },
        ],
    )
    txt = completion.choices[0].message.content()
    print(txt)
    return txt'''


'''def translate_malayalam_to_english(malayalam_text):
    try:
        translator = Translator(service_urls=["translate.googleapis.com"])
        translated_text = translator.translate(malayalam_text, src='ml', dest='en').text
        return translated_text
    except Exception as e:
        print(f"Error occurred during translation: {e}")
        return "" '''

def translate_malayalam_to_english(malayalam_text):
    try:
        translator = Translator()
        translation = translator.translate(malayalam_text, src='ml', dest='en')
        if translation:
            translated_text = translation.text
            return translated_text
        else:
            print("Translation failed or returned empty text.")
            return ""
    except Exception as e:
        print(f"Error occurred during translation: {e}")
        return ""

def translate_english_to_malayalam(english_text):
    translator = Translator()
    translated_text = translator.translate(english_text, src='en', dest='ml').text
    return translated_text


class SpeechToTextRecorder:
    def __init__(self, root):
        self.root = root
        self.root.title("Speech to Text Recorder")

        self.text_box = Text(root, wrap="word", height=10, width=40)
        self.text_box.pack(expand=True, fill="both")

        scrollbar = Scrollbar(self.root, orient="vertical", command=self.text_box.yview)
        scrollbar.pack(side="right", fill="y")
        self.text_box.config(yscrollcommand=scrollbar.set)

        self.start_button = tk.Button(root, text="Start Recording", command=self.start_recording)
        self.start_button.pack()

        self.recognizer = sr.Recognizer()

    def start_recording(self):
        self.start_button.config(state="disabled")
        threading.Thread(target=self.record_and_convert).start()

    def record_and_convert(self):
        try:
            self.text_box.delete(1.0, "end")
            self.text_box.insert("end", "Recording... Speak now.")
            duration = 10  # seconds
            fs = 44100
            myrecording = sd.rec(int(duration * fs), samplerate=fs, channels=1, dtype='int16')
            sd.wait()
            audio_data = np.hstack(myrecording)
            recorded_text = self.recognize_audio(audio_data)
            self.display_text(recorded_text)

        except Exception as e:
            messagebox.showerror("Error", f"Error occurred during conversion: {e}")
            self.start_button.config(state="normal")

    def recognize_audio(self, audio_data):
        audio = sr.AudioData(audio_data, sample_rate=44100, sample_width=2)
        try:
            recorded_text = self.recognizer.recognize_google(audio, language="ml-IN")
            return recorded_text
        except sr.UnknownValueError:
            return "Google Speech Recognition could not understand audio"
        except sr.RequestError as e:
            return f"Could not request results from Google Speech Recognition service; {e}"

    def display_text(self, text):
        self.text_box.delete(1.0, "end")
        self.text_box.insert("end", text + "\n***\n")

        translated_text = translate_malayalam_to_english(text)
        self.text_box.insert("end", translated_text + "\n***\n")

        response = chat_with_gpt(translated_text)
        self.text_box.insert("end", response + "\n***\n")

        translated_text1 = translate_english_to_malayalam(response)
        self.text_box.insert("end", translated_text1 + "\n***")

        self.start_button.config(state="normal")


if __name__ == "__main__":
    root = tk.Tk()
    root.geometry("800x600")
    app = SpeechToTextRecorder(root)
    try:
        root.mainloop()
    except KeyboardInterrupt:
        pass  # Handle KeyboardInterrupt gracefully
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       5 import tkinter as tk
#       6 from tkinter import Text, Scrollbar, messagebox
# ----> 7 from googletrans import Translator
#       8 import speech_recognition as sr
#       9 import threading
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\googletrans\__init__.py:6
#       2 __all__ = 'Translator',
#       3 __version__ = '4.0.0-rc.1'
# ----> 6 from googletrans.client import Translator
#       7 from googletrans.constants import LANGCODES, LANGUAGES  # noqa
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\googletrans\client.py:13
#      10 import json
#      12 import httpcore
# ---> 13 import httpx
#      14 from httpx import Timeout
#      16 from googletrans import urls, utils
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpx\__init__.py:2
#       1 from .__version__ import __description__, __title__, __version__
# ----> 2 from ._api import delete, get, head, options, patch, post, put, request, stream
#       3 from ._auth import Auth, BasicAuth, DigestAuth
#       4 from ._client import AsyncClient, Client
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpx\_api.py:3
#       1 import typing
# ----> 3 from ._client import Client, StreamContextManager
#       4 from ._config import DEFAULT_TIMEOUT_CONFIG
#       5 from ._models import Request, Response
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpx\_client.py:25
#      23 from ._status_codes import codes
#      24 from ._transports.asgi import ASGITransport
# ---> 25 from ._transports.wsgi import WSGITransport
#      26 from ._types import (
#      27     AuthTypes,
#      28     CertTypes,
#    (...)
#      37     VerifyTypes,
#      38 )
#      39 from ._utils import (
#      40     NetRCInfo,
#      41     get_environment_proxies,
#    (...)
#      44     warn_deprecated,
#      45 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpx\_transports\wsgi.py:19
#      15             return itertools.chain([chunk], body)
#      16     return []
# ---> 19 class WSGITransport(httpcore.SyncHTTPTransport):
#      20     """
#      21     A custom transport that handles sending requests directly to an WSGI app.
#      22     The simplest way to use this functionality is to use the `app` argument.
#    (...)
#      49     ```
#      50     """
#      52     def __init__(
#      53         self,
#      54         app: typing.Callable,
#    (...)
#      57         remote_addr: str = "127.0.0.1",
#      58     ) -> None:
#
# TypeError: str() argument 'encoding' must be str, not tuple

# %%
# !pip install httpcore
# Out:
# Requirement already satisfied: httpcore in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpcore) (0.9.0)
# Requirement already satisfied: h2==3.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpcore) (3.2.0)
# Requirement already satisfied: sniffio==1.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpcore) (1.3.1)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from h2==3.*->httpcore) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from h2==3.*->httpcore) (3.0.0)

# %%
# !pip install speech_recognition
# Out:
# ERROR: Could not find a version that satisfies the requirement speech_recognition (from versions: none)
# ERROR: No matching distribution found for speech_recognition

# %%
# !pip install SpeechRecognition
# !pip install openai
# Out:
# Requirement already satisfied: SpeechRecognition in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (3.10.3)
# Requirement already satisfied: requests>=2.26.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from SpeechRecognition) (2.31.0)
# Requirement already satisfied: typing-extensions in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from SpeechRecognition) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26.0->SpeechRecognition) (2024.2.2)
# Requirement already satisfied: openai in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (0.28.0)
# Requirement already satisfied: requests>=2.20 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.66.4)
# Requirement already satisfied: aiohttp in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai) (3.9.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai) (2024.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai) (1.9.4)
# Requirement already satisfied: colorama in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from tqdm->openai) (0.4.6)

# %%
# !pip install sounddevice
# Out:
# Requirement already satisfied: sounddevice in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (0.4.6)
# Requirement already satisfied: CFFI>=1.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from sounddevice) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from CFFI>=1.0->sounddevice) (2.22)

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (1.26.4)

# %%
import httpcore

setattr(httpcore, 'SyncHTTPTransport', 'AsyncHTTPProxy')

import tkinter as tk
from tkinter import Text, Scrollbar, messagebox
from googletrans import Translator
import speech_recognition as sr
import threading
import openai as OpenAI
# from openai import OpenAI
import sounddevice as sd
import numpy as np


openai.api_key="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"

def chat_with_gpt(prompt):
  completion = openai.Completion.create(
    engine="gpt-3.5-turbo-instruct",  # Replace with gpt-3.5-turbo-instruct
    prompt=prompt,
    max_tokens=150
  )
  txt = completion.choices[0].text
  print(txt)
  return txt

'''def chat_with_gpt(prompt):
    completion = openai.Completion.create(
        model= "text-davinci-002",     #"gpt-3.5-turbo",  # 
        messages=[
            {
                "role": "user",
                "content": prompt,
            },
        ],
    )
    txt = completion.choices[0].message.content()
    print(txt)
    return txt'''


'''def translate_malayalam_to_english(malayalam_text):
    try:
        translator = Translator(service_urls=["translate.googleapis.com"])
        translated_text = translator.translate(malayalam_text, src='ml', dest='en').text
        return translated_text
    except Exception as e:
        print(f"Error occurred during translation: {e}")
        return "" '''

def translate_malayalam_to_english(malayalam_text):
    try:
        translator = Translator()
        translation = translator.translate(malayalam_text, src='ml', dest='en')
        if translation:
            translated_text = translation.text
            return translated_text
        else:
            print("Translation failed or returned empty text.")
            return ""
    except Exception as e:
        print(f"Error occurred during translation: {e}")
        return ""

def translate_english_to_malayalam(english_text):
    translator = Translator()
    translated_text = translator.translate(english_text, src='en', dest='ml').text
    return translated_text


class SpeechToTextRecorder:
    def __init__(self, root):
        self.root = root
        self.root.title("Speech to Text Recorder")

        self.text_box = Text(root, wrap="word", height=10, width=40)
        self.text_box.pack(expand=True, fill="both")

        scrollbar = Scrollbar(self.root, orient="vertical", command=self.text_box.yview)
        scrollbar.pack(side="right", fill="y")
        self.text_box.config(yscrollcommand=scrollbar.set)

        self.start_button = tk.Button(root, text="Start Recording", command=self.start_recording)
        self.start_button.pack()

        self.recognizer = sr.Recognizer()

    def start_recording(self):
        self.start_button.config(state="disabled")
        threading.Thread(target=self.record_and_convert).start()

    def record_and_convert(self):
        try:
            self.text_box.delete(1.0, "end")
            self.text_box.insert("end", "Recording... Speak now.")
            duration = 10  # seconds
            fs = 44100
            myrecording = sd.rec(int(duration * fs), samplerate=fs, channels=1, dtype='int16')
            sd.wait()
            audio_data = np.hstack(myrecording)
            recorded_text = self.recognize_audio(audio_data)
            self.display_text(recorded_text)

        except Exception as e:
            messagebox.showerror("Error", f"Error occurred during conversion: {e}")
            self.start_button.config(state="normal")

    def recognize_audio(self, audio_data):
        audio = sr.AudioData(audio_data, sample_rate=44100, sample_width=2)
        try:
            recorded_text = self.recognizer.recognize_google(audio, language="ml-IN")
            return recorded_text
        except sr.UnknownValueError:
            return "Google Speech Recognition could not understand audio"
        except sr.RequestError as e:
            return f"Could not request results from Google Speech Recognition service; {e}"

    def display_text(self, text):
        self.text_box.delete(1.0, "end")
        self.text_box.insert("end", text + "\n***\n")

        translated_text = translate_malayalam_to_english(text)
        self.text_box.insert("end", translated_text + "\n***\n")

        response = chat_with_gpt(translated_text)
        self.text_box.insert("end", response + "\n***\n")

        translated_text1 = translate_english_to_malayalam(response)
        self.text_box.insert("end", translated_text1 + "\n***")

        self.start_button.config(state="normal")


if __name__ == "__main__":
    root = tk.Tk()
    root.geometry("800x600")
    app = SpeechToTextRecorder(root)
    try:
        root.mainloop()
    except KeyboardInterrupt:
        pass  # Handle KeyboardInterrupt gracefully
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 7
#       5 import tkinter as tk
#       6 from tkinter import Text, Scrollbar, messagebox
# ----> 7 from googletrans import Translator
#       8 import speech_recognition as sr
#       9 import threading
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\googletrans\__init__.py:6
#       2 __all__ = 'Translator',
#       3 __version__ = '4.0.0-rc.1'
# ----> 6 from googletrans.client import Translator
#       7 from googletrans.constants import LANGCODES, LANGUAGES  # noqa
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\googletrans\client.py:13
#      10 import json
#      12 import httpcore
# ---> 13 import httpx
#      14 from httpx import Timeout
#      16 from googletrans import urls, utils
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpx\__init__.py:2
#       1 from .__version__ import __description__, __title__, __version__
# ----> 2 from ._api import delete, get, head, options, patch, post, put, request, stream
#       3 from ._auth import Auth, BasicAuth, DigestAuth
#       4 from ._client import AsyncClient, Client
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpx\_api.py:3
#       1 import typing
# ----> 3 from ._client import Client, StreamContextManager
#       4 from ._config import DEFAULT_TIMEOUT_CONFIG
#       5 from ._models import Request, Response
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpx\_client.py:25
#      23 from ._status_codes import codes
#      24 from ._transports.asgi import ASGITransport
# ---> 25 from ._transports.wsgi import WSGITransport
#      26 from ._types import (
#      27     AuthTypes,
#      28     CertTypes,
#    (...)
#      37     VerifyTypes,
#      38 )
#      39 from ._utils import (
#      40     NetRCInfo,
#      41     get_environment_proxies,
#    (...)
#      44     warn_deprecated,
#      45 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpx\_transports\wsgi.py:19
#      15             return itertools.chain([chunk], body)
#      16     return []
# ---> 19 class WSGITransport(httpcore.SyncHTTPTransport):
#      20     """
#      21     A custom transport that handles sending requests directly to an WSGI app.
#      22     The simplest way to use this functionality is to use the `app` argument.
#    (...)
#      49     ```
#      50     """
#      52     def __init__(
#      53         self,
#      54         app: typing.Callable,
#    (...)
#      57         remote_addr: str = "127.0.0.1",
#      58     ) -> None:
#
# TypeError: str() argument 'encoding' must be str, not tuple

# %%
# !pip install httpx --upgrade
# Out:
# Requirement already satisfied: httpx in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (0.13.3)
# Collecting httpx
#   Using cached httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: anyio in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx) (4.3.0)
# Requirement already satisfied: certifi in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx) (2024.2.2)
# Collecting httpcore==1.* (from httpx)
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx) (2.10)
# Requirement already satisfied: sniffio in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: h11, httpcore, httpx
#   Attempting uninstall: h11
#     Found existing installation: h11 0.9.0
#     Uninstalling h11-0.9.0:
#       Successfully uninstalled h11-0.9.0
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 0.9.1
#     Uninstalling httpcore-0.9.1:
#       Successfully uninstalled httpcore-0.9.1
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.13.3
#     Uninstalling httpx-0.13.3:
#       Successfully uninstalled httpx-0.13.3
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# googletrans 4.0.0rc1 requires httpx==0.13.3, but you have httpx 0.27.0 which is incompatible.

# %%
# !pip install googletrans==3.0.0
# Out:
# Collecting googletrans==3.0.0
#   Using cached googletrans-3.0.0-py3-none-any.whl
# Collecting httpx==0.13.3 (from googletrans==3.0.0)
#   Using cached httpx-0.13.3-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: certifi in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans==3.0.0) (2024.2.2)
# Requirement already satisfied: hstspreload in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans==3.0.0) (2024.5.1)
# Requirement already satisfied: sniffio in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans==3.0.0) (1.3.1)
# Requirement already satisfied: chardet==3.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans==3.0.0) (3.0.4)
# Requirement already satisfied: idna==2.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans==3.0.0) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans==3.0.0) (1.5.0)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==3.0.0)
#   Using cached httpcore-0.9.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.0.0)
#   Using cached h11-0.9.0-py2.py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: h2==3.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.0.0) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.0.0) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.0.0) (3.0.0)
# Using cached httpx-0.13.3-py3-none-any.whl (55 kB)
# Using cached httpcore-0.9.1-py3-none-any.whl (42 kB)
# Using cached h11-0.9.0-py2.py3-none-any.whl (53 kB)
# Installing collected packages: h11, httpcore, httpx, googletrans
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.5
#     Uninstalling httpcore-1.0.5:
#       Successfully uninstalled httpcore-1.0.5
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.27.0
#     Uninstalling httpx-0.27.0:
#       Successfully uninstalled httpx-0.27.0
#   Attempting uninstall: googletrans
#     Found existing installation: googletrans 4.0.0rc1
#     Uninstalling googletrans-4.0.0rc1:
#       Successfully uninstalled googletrans-4.0.0rc1
# Successfully installed googletrans-3.0.0 h11-0.9.0 httpcore-0.9.1 httpx-0.13.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyterlab 4.1.8 requires httpx>=0.25.0, but you have httpx 0.13.3 which is incompatible.

# %%
# !pip uninstall httpx 0.13.3

# %%
# !pip install httpx==0.25.0
