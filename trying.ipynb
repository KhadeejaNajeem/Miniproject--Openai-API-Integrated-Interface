# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# Requirement already satisfied: googletrans==4.0.0-rc1 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (4.0.0rc1)
# Requirement already satisfied: httpx==0.13.3 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: certifi in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.6.2)
# Requirement already satisfied: hstspreload in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.6.1)
# Requirement already satisfied: sniffio in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Requirement already satisfied: chardet==3.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: idna==2.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: h2==3.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)

# %%
# !pip install httpx==0.13.3
# Out:
# Requirement already satisfied: httpx==0.13.3 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (0.13.3)
# Requirement already satisfied: certifi in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (2024.6.2)
# Requirement already satisfied: hstspreload in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (2024.6.1)
# Requirement already satisfied: sniffio in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (1.3.1)
# Requirement already satisfied: chardet==3.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (3.0.4)
# Requirement already satisfied: idna==2.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3) (0.9.0)
# Requirement already satisfied: h2==3.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3) (3.0.0)

# %%
# !pip install speechrecognition
# !pip install openai
# !pip install sounddevice
# !pip install numpy
# Out:
# Requirement already satisfied: speechrecognition in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (3.10.3)
# Requirement already satisfied: requests>=2.26.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from speechrecognition) (2.31.0)
# Requirement already satisfied: typing-extensions in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from speechrecognition) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26.0->speechrecognition) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26.0->speechrecognition) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26.0->speechrecognition) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26.0->speechrecognition) (2024.6.2)
# Requirement already satisfied: openai in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (0.28.0)
# Requirement already satisfied: requests>=2.20 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.66.4)
# Requirement already satisfied: aiohttp in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from openai) (3.9.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai) (2024.6.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai) (1.9.4)
# Requirement already satisfied: colorama in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from tqdm->openai) (0.4.6)
# Requirement already satisfied: sounddevice in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (0.4.6)
# Requirement already satisfied: CFFI>=1.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from sounddevice) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from CFFI>=1.0->sounddevice) (2.22)
# Requirement already satisfied: numpy in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (1.26.4)

# %%
# !pip show httpcore
# Out:
# Name: httpcore
# Version: 0.9.1
# Summary: A minimal low-level HTTP client.
# Home-page: https://github.com/encode/httpcore
# Author: Tom Christie
# Author-email: tom@tomchristie.com
# License: BSD
# Location: C:\Users\Najeem\AppData\Local\Programs\Python\Python312\Lib\site-packages
# Requires: h11, h2, sniffio
# Required-by: httpx

# %%
# !pip show googletrans
# Out:
# Name: googletrans
# Version: 4.0.0rc1
# Summary: Free Google Translate API for Python. Translates totally free of charge.
# Home-page: https://github.com/ssut/py-googletrans
# Author: SuHun Han
# Author-email: ssut@ssut.me
# License: MIT
# Location: C:\Users\Najeem\AppData\Local\Programs\Python\Python312\Lib\site-packages
# Requires: httpx
# Required-by:

# %%
import httpcore
print("Hello World")
# Out:
# Hello World

# %%
import httpcore

setattr(httpcore, 'SyncHTTPTransport', 'AsyncHTTPProxy')
import tkinter as tk
from tkinter import Text, Scrollbar, messagebox


# Install the required version of httpx
# !pip install httpx==0.13.3

from googletrans import Translator
import speech_recognition as sr
import threading
import openai
from openai import OpenAI
import sounddevice as sd
import numpy as np

'''openai.api_key = "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"'''
client = OpenAI(
    api_key="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"
)

def chat_with_gpt(prompt):
    completion = client.completions.create(
        model="gpt-3.5-turbo-instruct",  # Replace with gpt-3.5-turbo-instruct
        prompt=prompt,
        max_tokens=150
    )
    txt = completion.choices[0].text.strip()
    print(txt)
    return txt


'''def chat_with_gpt(prompt):
    completion = openai.Completion.create(
        engine="gpt-3.5-turbo-instruct",  # Replace with gpt-3.5-turbo-instruct
        prompt=prompt,
        max_tokens=150
    )
    txt = completion.choices[0].text
    print(txt)
    return txt'''

# Your translation functions...
def translate_malayalam_to_english(malayalam_text):
    try:
        translator = Translator()
        translation = translator.translate(malayalam_text, src='ml', dest='en')
        if translation:
            translated_text = translation.text
            return translated_text
        else:
            print("Translation failed or returned empty text.")
            return ""
    except Exception as e:
        print(f"Error occurred during translation: {e}")
        return ""


def translate_english_to_malayalam(english_text):
    translator = Translator()
    translated_text = translator.translate(english_text, src='en', dest='ml').text
    return translated_text

class SpeechToTextRecorder:
    def __init__(self, root):
        self.root = root
        self.root.title("Speech to Text Recorder")

        self.text_box = Text(root, wrap="word", height=10, width=40)
        self.text_box.pack(expand=True, fill="both")

        scrollbar = Scrollbar(self.root, orient="vertical", command=self.text_box.yview)
        scrollbar.pack(side="right", fill="y")
        self.text_box.config(yscrollcommand=scrollbar.set)

        self.start_button = tk.Button(root, text="Start Recording", command=self.start_recording)
        self.start_button.pack()

        self.recognizer = sr.Recognizer()

    def start_recording(self):
        self.start_button.config(state="disabled")
        threading.Thread(target=self.record_and_convert).start()

    def record_and_convert(self):
        try:
            self.text_box.delete(1.0, "end")
            self.text_box.insert("end", "Recording... Speak now.")
            duration = 10  # seconds
            fs = 44100
            myrecording = sd.rec(int(duration * fs), samplerate=fs, channels=1, dtype='int16')
            sd.wait()
            audio_data = np.hstack(myrecording)
            recorded_text = self.recognize_audio(audio_data)
            self.display_text(recorded_text)

        except Exception as e:
            messagebox.showerror("Error", f"Error occurred during conversion: {e}")
            self.start_button.config(state="normal")

    def recognize_audio(self, audio_data):
        audio = sr.AudioData(audio_data, sample_rate=44100, sample_width=2)
        try:
            recorded_text = self.recognizer.recognize_google(audio, language="ml-IN")
            return recorded_text
        except sr.UnknownValueError:
            return "Google Speech Recognition could not understand audio"
        except sr.RequestError as e:
            return f"Could not request results from Google Speech Recognition service; {e}"

    def display_text(self, text):
        self.text_box.delete(1.0, "end")
        self.text_box.insert("end", text + "\n***\n")

        translated_text = translate_malayalam_to_english(text)
        self.text_box.insert("end", translated_text + "\n***\n")

        response = chat_with_gpt(translated_text)
        self.text_box.insert("end", response + "\n***\n")

        translated_text1 = translate_english_to_malayalam(response)
        self.text_box.insert("end", translated_text1 + "\n***")

        self.start_button.config(state="normal")


if __name__ == "__main__":
    root = tk.Tk()
    root.geometry("800x600")
    app = SpeechToTextRecorder(root)
    try:
        root.mainloop()
    except KeyboardInterrupt:
        pass  # Handle KeyboardInterrupt gracefully
# Out:
# Requirement already satisfied: httpx==0.13.3 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (0.13.3)
# Requirement already satisfied: certifi in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (2024.6.2)
# Requirement already satisfied: hstspreload in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (2024.6.1)
# Requirement already satisfied: sniffio in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (1.3.1)
# Requirement already satisfied: chardet==3.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (3.0.4)
# Requirement already satisfied: idna==2.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3) (0.9.0)
# Requirement already satisfied: h2==3.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3) (3.0.0)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 11
#       8 # Install the required version of httpx
#       9 get_ipython().system('pip install httpx==0.13.3')
# ---> 11 from googletrans import Translator
#      12 import speech_recognition as sr
#      13 import threading
#
# File ~\OneDrive\Desktop\NewKernel\NEW-VENV\Lib\site-packages\googletrans\__init__.py:6
#       2 __all__ = 'Translator',
#       3 __version__ = '4.0.0-rc.1'
# ----> 6 from googletrans.client import Translator
#       7 from googletrans.constants import LANGCODES, LANGUAGES  # noqa
#
# File ~\OneDrive\Desktop\NewKernel\NEW-VENV\Lib\site-packages\googletrans\client.py:13
#      10 import json
#      12 import httpcore
# ---> 13 import httpx
#      14 from httpx import Timeout
#      16 from googletrans import urls, utils
#
# File ~\OneDrive\Desktop\NewKernel\NEW-VENV\Lib\site-packages\httpx\__init__.py:2
#       1 from .__version__ import __description__, __title__, __version__
# ----> 2 from ._api import delete, get, head, options, patch, post, put, request, stream
#       3 from ._auth import Auth, BasicAuth, DigestAuth
#       4 from ._client import AsyncClient, Client
#
# File ~\OneDrive\Desktop\NewKernel\NEW-VENV\Lib\site-packages\httpx\_api.py:3
#       1 import typing
# ----> 3 from ._client import Client, StreamContextManager
#       4 from ._config import DEFAULT_TIMEOUT_CONFIG
#       5 from ._models import Request, Response
#
# File ~\OneDrive\Desktop\NewKernel\NEW-VENV\Lib\site-packages\httpx\_client.py:25
#      23 from ._status_codes import codes
#      24 from ._transports.asgi import ASGITransport
# ---> 25 from ._transports.wsgi import WSGITransport
#      26 from ._types import (
#      27     AuthTypes,
#      28     CertTypes,
#    (...)
#      37     VerifyTypes,
#      38 )
#      39 from ._utils import (
#      40     NetRCInfo,
#      41     get_environment_proxies,
#    (...)
#      44     warn_deprecated,
#      45 )
#
# File ~\OneDrive\Desktop\NewKernel\NEW-VENV\Lib\site-packages\httpx\_transports\wsgi.py:19
#      15             return itertools.chain([chunk], body)
#      16     return []
# ---> 19 class WSGITransport(httpcore.SyncHTTPTransport):
#      20     """
#      21     A custom transport that handles sending requests directly to an WSGI app.
#      22     The simplest way to use this functionality is to use the `app` argument.
#    (...)
#      49     ```
#      50     """
#      52     def __init__(
#      53         self,
#      54         app: typing.Callable,
#    (...)
#      57         remote_addr: str = "127.0.0.1",
#      58     ) -> None:
#
# TypeError: str() argument 'encoding' must be str, not tuple

# %%
pip uninstall httpx googletrans
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping httpx as it is not installed.
# WARNING: Skipping googletrans as it is not installed.

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# Requirement already satisfied: googletrans==4.0.0-rc1 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (4.0.0rc1)
# Requirement already satisfied: httpx==0.13.3 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: certifi in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.6.2)
# Requirement already satisfied: hstspreload in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.6.1)
# Requirement already satisfied: sniffio in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Requirement already satisfied: chardet==3.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: idna==2.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: h2==3.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)

# %%
pip install httpx==0.13.3
# Out:
# Collecting httpx==0.13.3
#   Using cached httpx-0.13.3-py3-none-any.whl.metadata (25 kB)
# Collecting certifi (from httpx==0.13.3)
#   Using cached certifi-2024.6.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting hstspreload (from httpx==0.13.3)
#   Using cached hstspreload-2024.6.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: sniffio in c:\users\najeem\onedrive\desktop\newkernel\new-venv\lib\site-packages (from httpx==0.13.3) (1.3.1)
# Collecting chardet==3.* (from httpx==0.13.3)
#   Using cached chardet-3.0.4-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting idna==2.* (from httpx==0.13.3)
#   Using cached idna-2.10-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3)
#   Using cached rfc3986-1.5.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3)
#   Using cached httpcore-0.9.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3)
#   Using cached h11-0.9.0-py2.py3-none-any.whl.metadata (8.1 kB)
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3)
#   Using cached h2-3.2.0-py2.py3-none-any.whl.metadata (32 kB)
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3)
#   Using cached hyperframe-5.2.0-py2.py3-none-any.whl.metadata (7.2 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3)
#   Using cached hpack-3.0.0-py2.py3-none-any.whl.metadata (7.0 kB)
# Using cached httpx-0.13.3-py3-none-any.whl (55 kB)
# Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Using cached httpcore-0.9.1-py3-none-any.whl (42 kB)
# Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# Using cached h2-3.2.0-py2.py3-none-any.whl (65 kB)
# Using cached rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Using cached certifi-2024.6.2-py3-none-any.whl (164 kB)
# Using cached hstspreload-2024.6.1-py3-none-any.whl (1.2 MB)
# Using cached h11-0.9.0-py2.py3-none-any.whl (53 kB)
# Using cached hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Using cached hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, certifi, httpcore, httpx
#   Attempting uninstall: h11
#     Found existing installation: h11 0.12.0
#     Uninstalling h11-0.12.0:
#       Successfully uninstalled h11-0.12.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.7
#     Uninstalling idna-3.7:
#       Successfully uninstalled idna-3.7
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 0.13.6
#     Uninstalling httpcore-0.13.6:
#       Successfully uninstalled httpcore-0.13.6
# Successfully installed certifi-2024.6.2 chardet-3.0.4 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2024.6.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --force-reinstall googletrans==4.0.0-rc1
# Out:
# Collecting googletrans==4.0.0-rc1
#   Using cached googletrans-4.0.0rc1-py3-none-any.whl
# Collecting httpx==0.13.3 (from googletrans==4.0.0-rc1)
#   Using cached httpx-0.13.3-py3-none-any.whl.metadata (25 kB)
# Collecting certifi (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Using cached certifi-2024.6.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting hstspreload (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Using cached hstspreload-2024.6.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting sniffio (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Using cached chardet-3.0.4-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting idna==2.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Using cached idna-2.10-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Using cached rfc3986-1.5.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Using cached httpcore-0.9.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Using cached h11-0.9.0-py2.py3-none-any.whl.metadata (8.1 kB)
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Using cached h2-3.2.0-py2.py3-none-any.whl.metadata (32 kB)
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Using cached hyperframe-5.2.0-py2.py3-none-any.whl.metadata (7.2 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Using cached hpack-3.0.0-py2.py3-none-any.whl.metadata (7.0 kB)
# Using cached httpx-0.13.3-py3-none-any.whl (55 kB)
# Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Using cached httpcore-0.9.1-py3-none-any.whl (42 kB)
# Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached h2-3.2.0-py2.py3-none-any.whl (65 kB)
# Using cached rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Using cached certifi-2024.6.2-py3-none-any.whl (164 kB)
# Using cached hstspreload-2024.6.1-py3-none-any.whl (1.2 MB)
# Using cached h11-0.9.0-py2.py3-none-any.whl (53 kB)
# Using cached hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Using cached hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, sniffio, idna, hstspreload, h2, certifi, httpcore, httpx, googletrans
#   Attempting uninstall: rfc3986
#     Found existing installation: rfc3986 1.5.0
#     Uninstalling rfc3986-1.5.0:
#       Successfully uninstalled rfc3986-1.5.0
#   Attempting uninstall: hyperframe
#     Found existing installation: hyperframe 5.2.0
#     Uninstalling hyperframe-5.2.0:
#       Successfully uninstalled hyperframe-5.2.0
#   Attempting uninstall: hpack
#     Found existing installation: hpack 3.0.0
#     Uninstalling hpack-3.0.0:
#       Successfully uninstalled hpack-3.0.0
#   Attempting uninstall: h11
#     Found existing installation: h11 0.9.0
#     Uninstalling h11-0.9.0:
#       Successfully uninstalled h11-0.9.0
#   Attempting uninstall: chardet
#     Found existing installation: chardet 3.0.4
#     Uninstalling chardet-3.0.4:
#       Successfully uninstalled chardet-3.0.4
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.3.1
#     Uninstalling sniffio-1.3.1:
#       Successfully uninstalled sniffio-1.3.1
#   Attempting uninstall: idna
#     Found existing installation: idna 2.10
#     Uninstalling idna-2.10:
#       Successfully uninstalled idna-2.10
#   Attempting uninstall: hstspreload
#     Found existing installation: hstspreload 2024.6.1
#     Uninstalling hstspreload-2024.6.1:
#       Successfully uninstalled hstspreload-2024.6.1
#   Attempting uninstall: h2
#     Found existing installation: h2 3.2.0
#     Uninstalling h2-3.2.0:
#       Successfully uninstalled h2-3.2.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.6.2
#     Uninstalling certifi-2024.6.2:
#       Successfully uninstalled certifi-2024.6.2
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 0.9.1
#     Uninstalling httpcore-0.9.1:
#       Successfully uninstalled httpcore-0.9.1
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.13.3
#     Uninstalling httpx-0.13.3:
#       Successfully uninstalled httpx-0.13.3
# Successfully installed certifi-2024.6.2 chardet-3.0.4 googletrans-4.0.0rc1 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2024.6.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0 sniffio-1.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install httpx==0.13.3
# Out:
# Requirement already satisfied: httpx==0.13.3 in c:\users\najeem\onedrive\desktop\newkernel\new-venv\lib\site-packages (0.13.3)
# Requirement already satisfied: certifi in c:\users\najeem\onedrive\desktop\newkernel\new-venv\lib\site-packages (from httpx==0.13.3) (2024.6.2)
# Requirement already satisfied: hstspreload in c:\users\najeem\onedrive\desktop\newkernel\new-venv\lib\site-packages (from httpx==0.13.3) (2024.6.1)
# Requirement already satisfied: sniffio in c:\users\najeem\onedrive\desktop\newkernel\new-venv\lib\site-packages (from httpx==0.13.3) (1.3.1)
# Requirement already satisfied: chardet==3.* in c:\users\najeem\onedrive\desktop\newkernel\new-venv\lib\site-packages (from httpx==0.13.3) (3.0.4)
# Requirement already satisfied: idna==2.* in c:\users\najeem\onedrive\desktop\newkernel\new-venv\lib\site-packages (from httpx==0.13.3) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\najeem\onedrive\desktop\newkernel\new-venv\lib\site-packages (from httpx==0.13.3) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in c:\users\najeem\onedrive\desktop\newkernel\new-venv\lib\site-packages (from httpx==0.13.3) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\najeem\onedrive\desktop\newkernel\new-venv\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3) (0.9.0)
# Requirement already satisfied: h2==3.* in c:\users\najeem\onedrive\desktop\newkernel\new-venv\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\najeem\onedrive\desktop\newkernel\new-venv\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\najeem\onedrive\desktop\newkernel\new-venv\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3) (3.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
python --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 python --version
#
# NameError: name 'python' is not defined

# %%
try:
    from googletrans import Translator
    print("googletrans imported successfully!")
except ModuleNotFoundError as e:
    print("ModuleNotFoundError:", e)
# Out:
# googletrans imported successfully!

# %%
# !python test_googletrans.py
# Out:
# python: can't open file 'C:\\Users\\Najeem\\OneDrive\\Desktop\\NewKernel\\NEW-VENV\\test_googletrans.py': [Errno 2] No such file or directory

# %%
import httpcore

# %%
import httpcore

setattr(httpcore, 'SyncHTTPTransport', 'AsyncHTTPProxy')
import tkinter as tk
from tkinter import Text, Scrollbar, messagebox


# Install the required version of httpx
# !pip install httpx==0.13.3

from googletrans import Translator
import speech_recognition as sr
import threading
import openai
from openai import OpenAI
import sounddevice as sd
import numpy as np

'''openai.api_key = "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"'''
client = OpenAI(
    api_key="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"
)

def chat_with_gpt(prompt):
    completion = client.completions.create(
        model="gpt-3.5-turbo-instruct",  # Replace with gpt-3.5-turbo-instruct
        prompt=prompt,
        max_tokens=150
    )
    txt = completion.choices[0].text.strip()
    print(txt)
    return txt


'''def chat_with_gpt(prompt):
    completion = openai.Completion.create(
        engine="gpt-3.5-turbo-instruct",  # Replace with gpt-3.5-turbo-instruct
        prompt=prompt,
        max_tokens=150
    )
    txt = completion.choices[0].text
    print(txt)
    return txt'''

# Your translation functions...
def translate_malayalam_to_english(malayalam_text):
    try:
        translator = Translator()
        translation = translator.translate(malayalam_text, src='ml', dest='en')
        if translation:
            translated_text = translation.text
            return translated_text
        else:
            print("Translation failed or returned empty text.")
            return ""
    except Exception as e:
        print(f"Error occurred during translation: {e}")
        return ""


def translate_english_to_malayalam(english_text):
    translator = Translator()
    translated_text = translator.translate(english_text, src='en', dest='ml').text
    return translated_text

class SpeechToTextRecorder:
    def __init__(self, root):
        self.root = root
        self.root.title("Speech to Text Recorder")

        self.text_box = Text(root, wrap="word", height=10, width=40)
        self.text_box.pack(expand=True, fill="both")

        scrollbar = Scrollbar(self.root, orient="vertical", command=self.text_box.yview)
        scrollbar.pack(side="right", fill="y")
        self.text_box.config(yscrollcommand=scrollbar.set)

        self.start_button = tk.Button(root, text="Start Recording", command=self.start_recording)
        self.start_button.pack()

        self.recognizer = sr.Recognizer()

    def start_recording(self):
        self.start_button.config(state="disabled")
        threading.Thread(target=self.record_and_convert).start()

    def record_and_convert(self):
        try:
            self.text_box.delete(1.0, "end")
            self.text_box.insert("end", "Recording... Speak now.")
            duration = 10  # seconds
            fs = 44100
            myrecording = sd.rec(int(duration * fs), samplerate=fs, channels=1, dtype='int16')
            sd.wait()
            audio_data = np.hstack(myrecording)
            recorded_text = self.recognize_audio(audio_data)
            self.display_text(recorded_text)

        except Exception as e:
            messagebox.showerror("Error", f"Error occurred during conversion: {e}")
            self.start_button.config(state="normal")

    def recognize_audio(self, audio_data):
        audio = sr.AudioData(audio_data, sample_rate=44100, sample_width=2)
        try:
            recorded_text = self.recognizer.recognize_google(audio, language="ml-IN")
            return recorded_text
        except sr.UnknownValueError:
            return "Google Speech Recognition could not understand audio"
        except sr.RequestError as e:
            return f"Could not request results from Google Speech Recognition service; {e}"

    def display_text(self, text):
        self.text_box.delete(1.0, "end")
        self.text_box.insert("end", text + "\n***\n")

        translated_text = translate_malayalam_to_english(text)
        self.text_box.insert("end", translated_text + "\n***\n")

        response = chat_with_gpt(translated_text)
        self.text_box.insert("end", response + "\n***\n")

        translated_text1 = translate_english_to_malayalam(response)
        self.text_box.insert("end", translated_text1 + "\n***")

        self.start_button.config(state="normal")


if __name__ == "__main__":
    root = tk.Tk()
    root.geometry("800x600")
    app = SpeechToTextRecorder(root)
    try:
        root.mainloop()
    except KeyboardInterrupt:
        pass  # Handle KeyboardInterrupt gracefully
# Out:
# Requirement already satisfied: httpx==0.13.3 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (0.13.3)
# Requirement already satisfied: certifi in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (2024.6.2)
# Requirement already satisfied: hstspreload in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (2024.6.1)
# Requirement already satisfied: sniffio in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (1.3.1)
# Requirement already satisfied: chardet==3.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (3.0.4)
# Requirement already satisfied: idna==2.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3) (0.9.0)
# Requirement already satisfied: h2==3.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3) (3.0.0)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       8 # Install the required version of httpx
#       9 get_ipython().system('pip install httpx==0.13.3')
# ---> 11 from googletrans import Translator
#      12 import speech_recognition as sr
#      13 import threading
#
# File ~\OneDrive\Desktop\NewKernel\NEW-VENV\Lib\site-packages\googletrans\__init__.py:6
#       2 __all__ = 'Translator',
#       3 __version__ = '4.0.0-rc.1'
# ----> 6 from googletrans.client import Translator
#       7 from googletrans.constants import LANGCODES, LANGUAGES  # noqa
#
# File ~\OneDrive\Desktop\NewKernel\NEW-VENV\Lib\site-packages\googletrans\client.py:13
#      10 import json
#      12 import httpcore
# ---> 13 import httpx
#      14 from httpx import Timeout
#      16 from googletrans import urls, utils
#
# File ~\OneDrive\Desktop\NewKernel\NEW-VENV\Lib\site-packages\httpx\__init__.py:2
#       1 from .__version__ import __description__, __title__, __version__
# ----> 2 from ._api import delete, get, head, options, patch, post, put, request, stream
#       3 from ._auth import Auth, BasicAuth, DigestAuth
#       4 from ._client import AsyncClient, Client
#
# File ~\OneDrive\Desktop\NewKernel\NEW-VENV\Lib\site-packages\httpx\_api.py:3
#       1 import typing
# ----> 3 from ._client import Client, StreamContextManager
#       4 from ._config import DEFAULT_TIMEOUT_CONFIG
#       5 from ._models import Request, Response
#
# File ~\OneDrive\Desktop\NewKernel\NEW-VENV\Lib\site-packages\httpx\_client.py:25
#      23 from ._status_codes import codes
#      24 from ._transports.asgi import ASGITransport
# ---> 25 from ._transports.wsgi import WSGITransport
#      26 from ._types import (
#      27     AuthTypes,
#      28     CertTypes,
#    (...)
#      37     VerifyTypes,
#      38 )
#      39 from ._utils import (
#      40     NetRCInfo,
#      41     get_environment_proxies,
#    (...)
#      44     warn_deprecated,
#      45 )
#
# File ~\OneDrive\Desktop\NewKernel\NEW-VENV\Lib\site-packages\httpx\_transports\wsgi.py:19
#      15             return itertools.chain([chunk], body)
#      16     return []
# ---> 19 class WSGITransport(httpcore.SyncHTTPTransport):
#      20     """
#      21     A custom transport that handles sending requests directly to an WSGI app.
#      22     The simplest way to use this functionality is to use the `app` argument.
#    (...)
#      49     ```
#      50     """
#      52     def __init__(
#      53         self,
#      54         app: typing.Callable,
#    (...)
#      57         remote_addr: str = "127.0.0.1",
#      58     ) -> None:
#
# TypeError: str() argument 'encoding' must be str, not tuple

# %%
# !pip show googletrans
# Out:
# Name: googletrans
# Version: 4.0.0rc1
# Summary: Free Google Translate API for Python. Translates totally free of charge.
# Home-page: https://github.com/ssut/py-googletrans
# Author: SuHun Han
# Author-email: ssut@ssut.me
# License: MIT
# Location: C:\Users\Najeem\AppData\Local\Programs\Python\Python312\Lib\site-packages
# Requires: httpx
# Required-by:

# %%
# !pip --googletrans
# Out:
# Usage:
#   pip <command> [options]
#
# no such option: --googletrans

# %%
try:
    from googletrans import Translator
    print("googletrans imported successfully!")
except ModuleNotFoundError as e:
    print("ModuleNotFoundError:", e)
# Out:
# googletrans imported successfully!

# %%
# Ensure that we can import all necessary modules
try:
    from googletrans import Translator
    import speech_recognition as sr
    import openai
    import sounddevice as sd
    import numpy as np
    import tkinter as tk
    from tkinter import Text, Scrollbar, messagebox

    print("All imports were successful!")
except ModuleNotFoundError as e:
    print("ModuleNotFoundError:", e)
    raise

# Main script

# Set OpenAI API key
openai.api_key = "your_openai_api_key_here"

def chat_with_gpt(prompt):
    completion = openai.Completion.create(
        engine="gpt-3.5-turbo-instruct",  # Replace with gpt-3.5-turbo-instruct
        prompt=prompt,
        max_tokens=150
    )
    txt = completion.choices[0].text.strip()
    print(txt)
    return txt

def translate_malayalam_to_english(malayalam_text):
    try:
        translator = Translator()
        translation = translator.translate(malayalam_text, src='ml', dest='en')
        if translation:
            translated_text = translation.text
            return translated_text
        else:
            print("Translation failed or returned empty text.")
            return ""
    except Exception as e:
        print(f"Error occurred during translation: {e}")
        return ""

def translate_english_to_malayalam(english_text):
    translator = Translator()
    translated_text = translator.translate(english_text, src='en', dest='ml').text
    return translated_text

class SpeechToTextRecorder:
    def __init__(self, root):
        self.root = root
        self.root.title("Speech to Text Recorder")

        self.text_box = Text(root, wrap="word", height=10, width=40)
        self.text_box.pack(expand=True, fill="both")

        scrollbar = Scrollbar(self.root, orient="vertical", command=self.text_box.yview)
        scrollbar.pack(side="right", fill="y")
        self.text_box.config(yscrollcommand=scrollbar.set)

        self.start_button = tk.Button(root, text="Start Recording", command=self.start_recording)
        self.start_button.pack()

        self.recognizer = sr.Recognizer()

    def start_recording(self):
        self.start_button.config(state="disabled")
        threading.Thread(target=self.record_and_convert).start()

    def record_and_convert(self):
        try:
            self.text_box.delete(1.0, "end")
            self.text_box.insert("end", "Recording... Speak now.")
            duration = 10  # seconds
            fs = 44100
            myrecording = sd.rec(int(duration * fs), samplerate=fs, channels=1, dtype='int16')
            sd.wait()
            audio_data = np.hstack(myrecording)
            recorded_text = self.recognize_audio(audio_data)
            self.display_text(recorded_text)

        except Exception as e:
            messagebox.showerror("Error", f"Error occurred during conversion: {e}")
            self.start_button.config(state="normal")

    def recognize_audio(self, audio_data):
        audio = sr.AudioData(audio_data.tobytes(), sample_rate=44100, sample_width=2)
        try:
            recorded_text = self.recognizer.recognize_google(audio, language="ml-IN")
            return recorded_text
        except sr.UnknownValueError:
            return "Google Speech Recognition could not understand audio"
        except sr.RequestError as e:
            return f"Could not request results from Google Speech Recognition service; {e}"

    def display_text(self, text):
        self.text_box.delete(1.0, "end")
        self.text_box.insert("end", text + "\n***\n")

        translated_text = translate_malayalam_to_english(text)
        self.text_box.insert("end", translated_text + "\n***\n")

        response = chat_with_gpt(translated_text)
        self.text_box.insert("end", response + "\n***\n")

        translated_text1 = translate_english_to_malayalam(response)
        self.text_box.insert("end", translated_text1 + "\n***")

        self.start_button.config(state="normal")

if __name__ == "__main__":
    root = tk.Tk()
    root.geometry("800x600")
    app = SpeechToTextRecorder(root)
    try:
        root.mainloop()
    except KeyboardInterrupt:
        pass  # Handle KeyboardInterrupt gracefully
# Out:
# All imports were successful!
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Najeem\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py", line 1967, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Najeem\AppData\Local\Temp\ipykernel_15920\4281913477.py", line 69, in start_recording
#     threading.Thread(target=self.record_and_convert).start()
#     ^^^^^^^^^
# NameError: name 'threading' is not defined. Did you forget to import 'threading'

# %%
import httpcore

setattr(httpcore, 'SyncHTTPTransport', 'AsyncHTTPProxy')

# !pip install httpx==0.13.3
import tkinter as tk
from tkinter import Text, Scrollbar, messagebox
from googletrans import Translator
import speech_recognition as sr
import threading
import openai
from openai import OpenAI
import sounddevice as sd
import numpy as np

# Install the required version of httpx


'''openai.api_key = "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"'''
client = OpenAI(
    api_key="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"
)

def chat_with_gpt(prompt):
    completion = client.completions.create(
        model="gpt-3.5-turbo-instruct",  # Replace with gpt-3.5-turbo-instruct
        prompt=prompt,
        max_tokens=150
    )
    txt = completion.choices[0].text.strip()
    print(txt)
    return txt


'''def chat_with_gpt(prompt):
    completion = openai.Completion.create(
        engine="gpt-3.5-turbo-instruct",  # Replace with gpt-3.5-turbo-instruct
        prompt=prompt,
        max_tokens=150
    )
    txt = completion.choices[0].text
    print(txt)
    return txt'''

# Your translation functions...
def translate_malayalam_to_english(malayalam_text):
    try:
        translator = Translator()
        translation = translator.translate(malayalam_text, src='ml', dest='en')
        if translation:
            translated_text = translation.text
            return translated_text
        else:
            print("Translation failed or returned empty text.")
            return ""
    except Exception as e:
        print(f"Error occurred during translation: {e}")
        return ""


def translate_english_to_malayalam(english_text):
    translator = Translator()
    translated_text = translator.translate(english_text, src='en', dest='ml').text
    return translated_text

class SpeechToTextRecorder:
    def __init__(self, root):
        self.root = root
        self.root.title("Speech to Text Recorder")

        self.text_box = Text(root, wrap="word", height=10, width=40)
        self.text_box.pack(expand=True, fill="both")

        scrollbar = Scrollbar(self.root, orient="vertical", command=self.text_box.yview)
        scrollbar.pack(side="right", fill="y")
        self.text_box.config(yscrollcommand=scrollbar.set)

        self.start_button = tk.Button(root, text="Start Recording", command=self.start_recording)
        self.start_button.pack()

        self.recognizer = sr.Recognizer()

    def start_recording(self):
        self.start_button.config(state="disabled")
        threading.Thread(target=self.record_and_convert).start()

    def record_and_convert(self):
        try:
            self.text_box.delete(1.0, "end")
            self.text_box.insert("end", "Recording... Speak now.")
            duration = 10  # seconds
            fs = 44100
            myrecording = sd.rec(int(duration * fs), samplerate=fs, channels=1, dtype='int16')
            sd.wait()
            audio_data = np.hstack(myrecording)
            recorded_text = self.recognize_audio(audio_data)
            self.display_text(recorded_text)

        except Exception as e:
            messagebox.showerror("Error", f"Error occurred during conversion: {e}")
            self.start_button.config(state="normal")

    def recognize_audio(self, audio_data):
        audio = sr.AudioData(audio_data, sample_rate=44100, sample_width=2)
        try:
            recorded_text = self.recognizer.recognize_google(audio, language="ml-IN")
            return recorded_text
        except sr.UnknownValueError:
            return "Google Speech Recognition could not understand audio"
        except sr.RequestError as e:
            return f"Could not request results from Google Speech Recognition service; {e}"

    def display_text(self, text):
        self.text_box.delete(1.0, "end")
        self.text_box.insert("end", text + "\n***\n")

        translated_text = translate_malayalam_to_english(text)
        self.text_box.insert("end", translated_text + "\n***\n")

        response = chat_with_gpt(translated_text)
        self.text_box.insert("end", response + "\n***\n")

        translated_text1 = translate_english_to_malayalam(response)
        self.text_box.insert("end", translated_text1 + "\n***")

        self.start_button.config(state="normal")


if __name__ == "__main__":
    root = tk.Tk()
    root.geometry("800x600")
    app = SpeechToTextRecorder(root)
    try:
        root.mainloop()
    except KeyboardInterrupt:
        pass  # Handle KeyboardInterrupt gracefully
# Out:
# Requirement already satisfied: httpx==0.13.3 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (0.13.3)
# Requirement already satisfied: certifi in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (2024.6.2)
# Requirement already satisfied: hstspreload in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (2024.6.1)
# Requirement already satisfied: sniffio in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (1.3.1)
# Requirement already satisfied: chardet==3.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (3.0.4)
# Requirement already satisfied: idna==2.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3) (0.9.0)
# Requirement already satisfied: h2==3.* in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\najeem\appdata\local\programs\python\python312\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3) (3.0.0)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 12
#      10 import threading
#      11 import openai
# ---> 12 from openai import OpenAI
#      13 import sounddevice as sd
#      14 import numpy as np
#
# ImportError: cannot import name 'OpenAI' from 'openai' (C:\Users\Najeem\OneDrive\Desktop\NewKernel\NEW-VENV\Lib\site-packages\openai\__init__.py)

# %%
try:
    import httpcore
    import tkinter as tk
    from tkinter import Text, Scrollbar, messagebox
    from googletrans import Translator
    import speech_recognition as sr
    import threading
    import openai
    import sounddevice as sd
    import numpy as np

    print("All imports were successful!")
except ModuleNotFoundError as e:
    print("ModuleNotFoundError:", e)
    raise

# Set OpenAI API key
openai.api_key = "sk-proj-84BPUxNqqe0KGbh2F5OjT3BlbkFJEfmELUQ0krQEJL9iCv38"

def chat_with_gpt(prompt):
    completion = openai.Completion.create(
        engine="gpt-3.5-turbo-instruct",  # Replace with gpt-3.5-turbo-instruct
        prompt=prompt,
        max_tokens=150
    )
    txt = completion.choices[0].text.strip()
    print(txt)
    return txt

def translate_malayalam_to_english(malayalam_text):
    try:
        translator = Translator()
        translation = translator.translate(malayalam_text, src='ml', dest='en')
        if translation:
            translated_text = translation.text
            return translated_text
        else:
            print("Translation failed or returned empty text.")
            return ""
    except Exception as e:
        print(f"Error occurred during translation: {e}")
        return ""

def translate_english_to_malayalam(english_text):
    translator = Translator()
    translated_text = translator.translate(english_text, src='en', dest='ml').text
    return translated_text

class SpeechToTextRecorder:
    def __init__(self, root):
        self.root = root
        self.root.title("Speech to Text Recorder")

        self.text_box = Text(root, wrap="word", height=10, width=40)
        self.text_box.pack(expand=True, fill="both")

        scrollbar = Scrollbar(self.root, orient="vertical", command=self.text_box.yview)
        scrollbar.pack(side="right", fill="y")
        self.text_box.config(yscrollcommand=scrollbar.set)

        self.start_button = tk.Button(root, text="Start Recording", command=self.start_recording)
        self.start_button.pack()

        self.recognizer = sr.Recognizer()

    def start_recording(self):
        self.start_button.config(state="disabled")
        threading.Thread(target=self.record_and_convert).start()

    def record_and_convert(self):
        try:
            self.text_box.delete(1.0, "end")
            self.text_box.insert("end", "Recording... Speak now.")
            duration = 10  # seconds
            fs = 44100
            myrecording = sd.rec(int(duration * fs), samplerate=fs, channels=1, dtype='int16')
            sd.wait()
            audio_data = np.hstack(myrecording)
            recorded_text = self.recognize_audio(audio_data)
            self.display_text(recorded_text)

        except Exception as e:
            messagebox.showerror("Error", f"Error occurred during conversion: {e}")
            self.start_button.config(state="normal")

    def recognize_audio(self, audio_data):
        audio = sr.AudioData(audio_data.tobytes(), sample_rate=44100, sample_width=2)
        try:
            recorded_text = self.recognizer.recognize_google(audio, language="ml-IN")
            return recorded_text
        except sr.UnknownValueError:
            return "Google Speech Recognition could not understand audio"
        except sr.RequestError as e:
            return f"Could not request results from Google Speech Recognition service; {e}"

    def display_text(self, text):
        self.text_box.delete(1.0, "end")
        self.text_box.insert("end", text + "\n***\n")

        translated_text = translate_malayalam_to_english(text)
        self.text_box.insert("end", translated_text + "\n***\n")

        response = chat_with_gpt(translated_text)
        self.text_box.insert("end", response + "\n***\n")

        translated_text1 = translate_english_to_malayalam(response)
        self.text_box.insert("end", translated_text1 + "\n***")

        self.start_button.config(state="normal")

if __name__ == "__main__":
    root = tk.Tk()
    root.geometry("800x600")
    app = SpeechToTextRecorder(root)
    try:
        root.mainloop()
    except KeyboardInterrupt:
        pass  # Handle KeyboardInterrupt gracefully
# Out:
# All imports were successful!
